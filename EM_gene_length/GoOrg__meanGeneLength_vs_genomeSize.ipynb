# %% [markdown]
# # Mean vs genome
# **in the protein coding gene length distributions for the different species**

# %% [markdown]
# ## Import python modules

# %%
import pandas as pd
import numpy as np
from scipy import stats
from plotnine import *

import sys
sys.path.append('../../gene_length/gl_lib/')
import gl_constants as c
import gl_plot as gl_p

# %% [markdown]
# ## The protein coding gene length distributions for the different species

# %% [markdown]
# ### Retrieving the statistical descriptions of the gene length's distributions

# %% [markdown]
# #### Statistical description

# %%
# statistics on length distributions 
#stat_file = "/home/emuro/git/github/gene_length/main_tables/stat_protCodGenes.tsv" # original file
stat_file = "/home/emuro/git/github/EM_geneLength_nature/working_on_tables/analysis/group_of_organisms/stat_protCodGenes_withGofOrg_v2.0.tsv" # group of orgn
print("The statistical descriptions of the protein coding gene distributions " + \
    "for the different species is in:\n", stat_file, "\n")

# retrieve data and diminish the number of columns
stat_df = pd.read_csv(stat_file, low_memory=False, sep="\t")
#stat_df = stat_df[["division_both_dbs", "species", "taxonomy_id","count", "mean", "var", "log10_mean", "log10_var"]]
stat_df = stat_df[["division_both_dbs", "species", "taxonomy_id","count", "mean", "var", "log10_mean", "log10_var", "g_orgs"]]

# visualize data
if 1:
    pd.set_option('display.max_columns', len(stat_df.columns))
    display(stat_df.sample(2))
    print(stat_df.shape)
    print(stat_df["division_both_dbs"].value_counts())
# Out:
# The statistical descriptions of the protein coding gene distributions for the different species is in:
#  /home/emuro/git/github/EM_geneLength_nature/working_on_tables/analysis/group_of_organisms/stat_protCodGenes_withGofOrg_v2.0.tsv
#      division_both_dbs                                          species  \
# 1110           archaea  candidatus_parvarchaeota_archaeon_gca_003202545
# 589            archaea        methanosarcina_mazei_wwm610_gca_000970165
#
#       taxonomy_id  count        mean            var  log10_mean  log10_var  \
# 1110      2077140    396  776.345960  308021.209123    2.795229    0.08255
# 589       1434117   3271  921.289514  425480.129306    2.866294    0.08964
#
#        g_orgs
# 1110  Archaea
# 589   Archaea
# (33627, 9)
# division_both_dbs
# bacteria         30714
# archaea           1229
# fungi             1014
# protists           237
# vertebrates        222
# invertebrates      115
# plants              96
# Name: count, dtype: int64

# %% [markdown]
# ## Get the genome size

# %%
# statistics on length distributions 
stat2_file = "/home/emuro/git/github/bioinf-genome_length/ensembl__taxid_species_goldenPath_division.tsv.bz2"
print("The genome sizes in bp, that I downloaded, " + \
    "for the different species is in:\n", stat2_file, "\n")

# retrieve data and diminish the number of columns
stat2_df = pd.read_csv(stat2_file, compression="bz2", low_memory=False, sep="\t")
#stat2_df = stat_df[["division_both_dbs", "species", "taxonomy_id","count", "mean", "var", "log10_mean", "log10_var"]]
stat2_df = stat2_df.rename(columns={"taxid": "taxonomy_id", "golden_path": "genome"})
# visualize data
if 1:
    pd.set_option('display.max_columns', len(stat2_df.columns))
#gl_p.plot_taylor_genes(df2plot, col_x, col_y, x_lab, y_lab, title, legends_by, bool_show_regression)
    display(stat2_df.sample(2))
    print(stat2_df.shape)
    print(stat2_df["division"].value_counts())
print(stat_df["division_both_dbs"].value_counts())
# Out:
# The genome sizes in bp, that I downloaded, for the different species is in:
#  /home/emuro/git/github/bioinf-genome_length/ensembl__taxid_species_goldenPath_division.tsv.bz2
#        taxonomy_id                                            species  \
# 25303        97473  pseudomonas_marginalis_pv_marginalis_gca_00370...
# 2989        544580                     actinomyces_oris_gca_001937365
#
#         genome         division
# 25303  6546442  EnsemblBacteria
# 2989   3046442  EnsemblBacteria
# (33022, 4)
# division
# EnsemblBacteria       31332
# EnsemblFungi           1014
# EnsemblProtists         237
# EnsemblVertebrates      227
# EnsemblMetazoa          115
# EnsemblPlants            96
# EnsemblViruses            1
# Name: count, dtype: int64
# division_both_dbs
# bacteria         30714
# archaea           1229
# fungi             1014
# protists           237
# vertebrates        222
# invertebrates      115
# plants              96
# Name: count, dtype: int64

# %% [markdown]
# ## Merge genome size column

# %% [raw]
# # merge data frames
# stat_df = (
#     pd.merge(
#         stat_df, stat2_df,
#         how='left',
#         left_on=['taxonomy_id', 'species'], right_on=['taxonomy_id', 'species']
#         )
#         .fillna({'genome':'NaN'})
# )
# # Counting NaN values in the 'golden_path' column
# #print(stat2_df['genome'].isna().sum())
#
#
# # visualize data
# if 1:
#     print("stat_df")
#     pd.set_option('display.max_columns', len(stat_df.columns))
#     display(stat_df.sample(2))
#     print(stat_df.shape)

# %%
# merge data frames
print(stat_df.shape)
print(stat2_df.shape)
print("Duplicados en stat_df:")
print(stat_df.duplicated(subset=['taxonomy_id', 'species']).sum())
print("Duplicados en stat2_df:")
print(stat2_df.duplicated(subset=['taxonomy_id', 'species']).sum())

stat_df = stat_df.drop_duplicates(subset=['taxonomy_id', 'species'])
stat2_df = stat2_df.drop_duplicates(subset=['taxonomy_id', 'species'])
print(stat_df.shape)
print(stat2_df.shape)


stat3_df = (
    # Perform an inner merge on 'key1' and 'key2'
    pd.merge(stat_df, stat2_df, on=['taxonomy_id', 'species'], how='inner')
)
# Counting NaN values in the 'golden_path' column
#print(stat2_df['genome'].isna().sum())

# visualize data
if 1:
    print("stat3_df")
    pd.set_option('display.max_columns', len(stat3_df.columns))
    display(stat3_df.sample(2))
    print(stat3_df.shape)
    stat3_df = stat3_df.dropna()
    print(stat3_df.shape)
# Out:
# (33627, 9)
# (33022, 4)
# Duplicados en stat_df:
# 682
# Duplicados en stat2_df:
# 3
# (32945, 9)
# (33019, 4)
# stat3_df
#       division_both_dbs                            species  taxonomy_id  \
# 23692          bacteria  pontibacter_virosus_gca_003096355      1765052
# 22624          bacteria      taibaiella_soli_gca_003236175      1649169
#
#        count         mean            var  log10_mean  log10_var    g_orgs  \
# 23692   4289   989.221730  578067.225778    2.890826   0.093564  Bacteria
# 22624   4297  1078.202467  857189.099594    2.921357   0.092842  Bacteria
#
#         genome         division
# 23692  4884877  EnsemblBacteria
# 22624  5387132  EnsemblBacteria
# (32945, 11)
# (32716, 11)

# %% [markdown]
# ## mean vs. genome size (represented in $log_{10}$ scale)
# ### Protein coding gene's length

# %%
col_x = "mean"  
col_y = "genome"  
legends_by = "division_both_dbs"

title = "Protein coding genes" # "Uniprot, reference Proteomes (protein length)"
x_lab = "Mean gene length"   
y_lab = "Genome (bp)"
#y_lab = "Number of prot. cod. genes"
bool_show_regression = True

df2plot = stat3_df.copy()
#df2plot["genome"] = df2plot["genome"] - df2plot["count"] * df2plot["mean"]
if 0:
    print(df2plot.shape)

# Sort division_both_dbs in order to plot the color of the clades in order
if 0:
    print(df2plot.division_both_dbs.unique())
df2plot.division_both_dbs = pd.Categorical(df2plot.division_both_dbs, 
                                categories=c.ORG_GROUPS,           
                                ordered=True)
df2plot.sort_values('division_both_dbs', inplace=True)

p = (   
        ggplot(df2plot, aes(col_x, col_y, color=legends_by)) + 
        geom_point(size=0.15) + #, alpha=0.4 + # color, fill )
        geom_smooth(method="lm", color="green", size=0.25, span=.8) +
        labs(title=title, x=x_lab, y=y_lab) 
        + scale_color_manual(values=c.COLOR_ORG_GROUPS) 
        + labs(color='Group of organisms') # legend title
        + scale_x_log10(breaks=[10 ** power for power in range(6)])#,
        #  limits=[min(df2plot[col_x].to_list())/2, 2*max(df2plot[col_x].to_list())]) 
        + scale_y_log10(breaks = [10**power for power in range(11)])#, 
        #  limits = [min(df2plot[col_y].to_list())/2,2*max(df2plot[col_y].to_list())])#, labels=scientific_format(digits=2)
    ) + theme(legend_position=(0.95,0.2), legend_key_size=2, \
        legend_background=element_rect(fill='grey', alpha=0.01)) #+ \
        #    annotate('text', x=0.01*max(df2plot[col_x].to_list()), \
        #        y=0.65*max(df2plot[col_y].to_list()), label=txt,size=9,color="black")

p.show()


#gl_p.plot_taylor_genes(df2plot, col_x, col_y, x_lab, y_lab, title, legends_by, bool_show_regression)
if 1:
    pd.set_option('display.max_columns', len(df2plot.columns))
    display(df2plot.sample(2))
    print(df2plot.shape)
    #print(df2plot["division"].value_counts())
    print(df2plot["division_both_dbs"].value_counts())
# Out:
#      division_both_dbs                              species  taxonomy_id  \
# 9096          bacteria    thermus_scotoductus_gca_003959205        37636
# 6684          bacteria  enterococcus_faecalis_gca_005238155         1351
#
#       count        mean            var  log10_mean  log10_var    g_orgs  \
# 9096   2558  781.878812  283711.599699    2.796952   0.089525  Bacteria
# 6684   2759  900.119971  407905.070808    2.848373   0.102588  Bacteria
#
#        genome         division
# 9096  2328641  EnsemblBacteria
# 6684  2809536  EnsemblBacteria
# (32716, 11)
# division_both_dbs
# bacteria         29890
# archaea           1213
# fungi              991
# protists           237
# vertebrates        206
# plants              93
# invertebrates       86
# Name: count, dtype: int64

# %% [markdown]
# #### Note:
# $\sigma^{2} = a . \mu^{\beta}$
# Because the regression line is:
# $\log(\sigma^{2}) = \log(a) + \beta log(\mu) $

# %%
col_x = "mean"  
col_y = "genome"  
legends_by = "g_orgs"

title = "Protein coding genes" # "Uniprot, reference Proteomes (protein length)"
x_lab = "Mean gene length"   
y_lab = "Genome (bp)"
#y_lab = "Number of prot. cod. genes"
bool_show_regression = True

df2plot = stat3_df.copy()
df2plot = df2plot[df2plot['division_both_dbs'] == 'vertebrates']

#df2plot["genome"] = df2plot["genome"] - df2plot["count"] * df2plot["mean"]
if 0:
    print(df2plot.shape)

# Sort division_both_dbs in order to plot the color of the clades in order
if 0:
    print(df2plot.legends_by.unique())
df2plot.division_both_dbs = pd.Categorical(df2plot.g_orgs, 
                                categories=c.ORG_GROUPS,           
                                ordered=True)
df2plot.sort_values('g_orgs', inplace=True)

p = (   
        ggplot(df2plot, aes(col_x, col_y, color=legends_by)) + 
        geom_point(size=0.15) + #, alpha=0.4 + # color, fill )
        geom_smooth(method="lm", color="green", size=0.25, span=.8) +
        labs(title=title, x=x_lab, y=y_lab) 
        + scale_color_manual(values=c.COLOR_ORG_GROUPS) 
        + labs(color='Group of organisms') # legend title
        + scale_x_log10(breaks=[10 ** power for power in range(6)])#,
        #  limits=[min(df2plot[col_x].to_list())/2, 2*max(df2plot[col_x].to_list())]) 
        + scale_y_log10(breaks = [10**power for power in range(11)])#, 
        #  limits = [min(df2plot[col_y].to_list())/2,2*max(df2plot[col_y].to_list())])#, labels=scientific_format(digits=2)
    ) + theme(legend_position=(0.95,0.2), legend_key_size=2, \
        legend_background=element_rect(fill='grey', alpha=0.01)) #+ \
        #    annotate('text', x=0.01*max(df2plot[col_x].to_list()), \
        #        y=0.65*max(df2plot[col_y].to_list()), label=txt,size=9,color="black")

p.show()


#gl_p.plot_taylor_genes(df2plot, col_x, col_y, x_lab, y_lab, title, legends_by, bool_show_regression)
if 1:
    pd.set_option('display.max_columns', len(df2plot.columns))
    display(df2plot.sample(2))
    print(df2plot.shape)
    #print(df2plot["division"].value_counts())
    print(df2plot["division_both_dbs"].value_counts())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 42
#      26 p = (
#      27         ggplot(df2plot, aes(col_x, col_y, color=legends_by)) +
#      28         geom_point(size=0.15) + #, alpha=0.4 + # color, fill )
#    (...)     37     ) + theme(legend_position=(0.95,0.2), legend_key_size=2, \
#      38         legend_background=element_rect(fill='grey', alpha=0.01)) #+ \
#      39         #    annotate('text', x=0.01*max(df2plot[col_x].to_list()), \
#      40         #        y=0.65*max(df2plot[col_y].to_list()), label=txt,size=9,color="black")
# ---> 42 p.show()
#      45 #gl_p.plot_taylor_genes(df2plot, col_x, col_y, x_lab, y_lab, title, legends_by, bool_show_regression)
#      46 if 1:
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/plotnine/ggplot.py:153, in ggplot.show(self)
#     144 """
#     145 Show plot using the matplotlib backend set by the user
#     146
#     147 Users should prefer this method instead of printing or repring
#     148 the object.
#     149 """
#     150 if is_inline_backend() or is_quarto_environment():
#     151     # Take charge of the display because we have to make
#     152     # adjustments for retina output.
# --> 153     self._display()
#     154 else:
#     155     self.draw(show=True)
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/plotnine/ggplot.py:181, in ggplot._display(self)
#     179 figure_size_px = self.theme._figure_size_px
#     180 buf = BytesIO()
# --> 181 self.save(buf, format=save_format, verbose=False)
#     182 display_func = get_display_function(format, figure_size_px)
#     183 display_func(buf.getvalue())
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/plotnine/ggplot.py:673, in ggplot.save(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     624 def save(
#     625     self,
#     626     filename: Optional[str | Path | BytesIO] = None,
#    (...)    635     **kwargs: Any,
#     636 ):
#     637     """
#     638     Save a ggplot object as an image file
#     639
#    (...)    671         Additional arguments to pass to matplotlib `savefig()`.
#     672     """
# --> 673     sv = self.save_helper(
#     674         filename=filename,
#     675         format=format,
#     676         path=path,
#     677         width=width,
#     678         height=height,
#     679         units=units,
#     680         dpi=dpi,
#     681         limitsize=limitsize,
#     682         verbose=verbose,
#     683         **kwargs,
#     684     )
#     686     with plot_context(self).rc_context:
#     687         sv.figure.savefig(**sv.kwargs)
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/plotnine/ggplot.py:621, in ggplot.save_helper(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     618 if dpi is not None:
#     619     self.theme = self.theme + theme(dpi=dpi)
# --> 621 figure = self.draw(show=False)
#     622 return mpl_save_view(figure, fig_kwargs)
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/plotnine/ggplot.py:278, in ggplot.draw(self, show)
#     276 self = deepcopy(self)
#     277 with plot_context(self, show=show):
# --> 278     self._build()
#     280     # setup
#     281     self.figure, self.axs = self.facet.setup(self)
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/plotnine/ggplot.py:406, in ggplot._build(self)
#     403     layers.map(npscales)
#     405 # Train coordinate system
# --> 406 layout.setup_panel_params(self.coordinates)
#     408 # fill in the defaults
#     409 layers.use_defaults_after_scale(scales)
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/plotnine/facets/layout.py:198, in Layout.setup_panel_params(self, coord)
#     196 for i, j in self.layout[cols].itertuples(index=False):
#     197     i, j = i - 1, j - 1
# --> 198     params = coord.setup_panel_params(
#     199         self.panel_scales_x[i], self.panel_scales_y[j]
#     200     )
#     201     self.panel_params.append(params)
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/plotnine/coords/coord_cartesian.py:88, in coord_cartesian.setup_panel_params(self, scale_x, scale_y)
#      84     sv = scale.view(limits=coord_limits, range=ranges.range)
#      85     return sv
#      87 out = panel_view(
# ---> 88     x=get_scale_view(scale_x, self.limits.x),
#      89     y=get_scale_view(scale_y, self.limits.y),
#      90 )
#      91 return out
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/plotnine/coords/coord_cartesian.py:84, in coord_cartesian.setup_panel_params.<locals>.get_scale_view(scale, limits)
#      80 expansion = scale.default_expansion(expand=self.expand)
#      81 ranges = scale.expand_limits(
#      82     scale.final_limits, expansion, coord_limits, identity_trans()
#      83 )
# ---> 84 sv = scale.view(limits=coord_limits, range=ranges.range)
#      85 return sv
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/plotnine/scales/scale_continuous.py:328, in scale_continuous.view(self, limits, range)
#     325 labels = self.get_labels(breaks)
#     327 ubreaks = self.get_breaks(range)
# --> 328 minor_breaks = self.get_minor_breaks(ubreaks, range)
#     330 sv = scale_view(
#     331     scale=self,
#     332     aesthetics=self.aesthetics,
#    (...)    338     minor_breaks=minor_breaks,
#     339 )
#     340 return sv
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/plotnine/scales/scale_continuous.py:472, in scale_continuous.get_minor_breaks(self, major, limits)
#     470     minor_breaks = []
#     471 elif self.minor_breaks is True:
# --> 472     minor_breaks: Sequence[float] = self._trans.minor_breaks(
#     473         major, limits
#     474     )  # pyright: ignore
#     475 elif isinstance(self.minor_breaks, int):
#     476     minor_breaks: Sequence[float] = self._trans.minor_breaks(
#     477         major,
#     478         limits,
#     479         self.minor_breaks,  # pyright: ignore
#     480     )
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/mizani/transforms.py:168, in trans.minor_breaks(self, major, limits, n)
#     164 """
#     165 Calculate minor_breaks
#     166 """
#     167 if self.minor_breaks_func is not None:
# --> 168     return self.minor_breaks_func(major, limits, n)
#     170 n = 1 if n is None else n
#     172 # minor_breaks_trans undoes the transformation and
#     173 # then calculates the breaks. If the domain/dataspace
#     174 # numerical, the calculation will fail.
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/mizani/breaks.py:377, in minor_breaks_trans.__call__(self, major, limits, n)
#     374 if n is None:
#     375     n = self.n
# --> 377 major = self._extend_breaks(major)
#     378 major = self.trans.inverse(major)
#     379 limits = self.trans.inverse(limits)
#
# File ~/python-my_venv/python3.12/my_env/lib/python3.12/site-packages/mizani/breaks.py:399, in minor_breaks_trans._extend_breaks(self, major)
#     397 is_log = trans.__name__.startswith("log")
#     398 diff = np.diff(major)
# --> 399 step = diff[0]
#     400 if is_log and all(diff == step):
#     401     major = np.hstack([major[0] - step, major, major[-1] + step])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
